# %%
import pandas as pd
import matplotlib

# %%
df_orig  = pd.read_json('myfile.json') # load data in
df= pd.DataFrame(list(df_orig.sensors)) # get data
df['timestamp'] = df_orig.timestamp
df
# Out:
#       Cond  DOpct   Sal   Temp   Turb    pH                 timestamp
# 0    531.8  74.25  0.30  17.38   2.64  7.37 2023-09-28 00:00:00+00:00
# 1    540.3  74.74  0.31  17.41   2.63  7.37 2023-09-28 00:15:00+00:00
# 2    554.8  73.97  0.32  17.45   3.21  7.37 2023-09-28 00:30:00+00:00
# 3    566.3  71.13  0.32  17.44   2.62  7.37 2023-09-28 00:45:00+00:00
# 4    568.7  70.85  0.33  17.41   2.51  7.37 2023-09-28 01:00:00+00:00
# ..     ...    ...   ...    ...    ...   ...                       ...
# 187  152.4  84.30  0.09  15.21  14.00  7.39 2023-09-29 22:45:00+00:00
# 188  156.7  84.20  0.09  15.22  12.64  7.39 2023-09-29 23:00:00+00:00
# 189  159.0  83.30  0.09  15.22  12.85  7.38 2023-09-29 23:15:00+00:00
# 190  167.2  83.50  0.10  15.22  21.27  7.38 2023-09-29 23:30:00+00:00
# 191  160.2  82.70  0.09  15.22  20.28  7.38 2023-09-29 23:45:00+00:00
#
# [192 rows x 7 columns]

# %%
# %matplotlib inline
df = pd.read_json('myfile.json') # load data in
df = pd.DataFrame(list(df.sensors)) # get data
fig = df.plot(kind='line', title=['Conductivity','Dissolved Oxygen','Salinity','Temperature','Turbidly','pH'],
        figsize=(20, 16), fontsize=13, subplots=True,grid=True)
