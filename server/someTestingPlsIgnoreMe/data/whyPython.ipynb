# %%
import pandas as pd
import matplotlib

# %%
df_orig  = pd.read_json('myfile.json') # load data in
df= pd.DataFrame(list(df_orig.sensors)) # get data
df['timestamp'] = df_orig.timestamp
df
# Out:
#        Cond  DOpct   Sal   Temp   Turb    pH                 timestamp
# 0     527.8  60.17  0.26  23.07   9.81  7.47 2023-09-01 00:00:00+00:00
# 1     528.8  57.94  0.27  23.09   9.26  7.46 2023-09-01 00:15:00+00:00
# 2     529.1  57.38  0.27  23.10   9.42  7.45 2023-09-01 00:30:00+00:00
# 3     528.8  60.32  0.26  23.11  10.16  7.44 2023-09-01 00:45:00+00:00
# 4     528.7  62.02  0.26  23.11  10.66  7.44 2023-09-01 01:00:00+00:00
# ...     ...    ...   ...    ...    ...   ...                       ...
# 2779  152.4  84.30  0.09  15.21  14.00  7.39 2023-09-29 22:45:00+00:00
# 2780  156.7  84.20  0.09  15.22  12.64  7.39 2023-09-29 23:00:00+00:00
# 2781  159.0  83.30  0.09  15.22  12.85  7.38 2023-09-29 23:15:00+00:00
# 2782  167.2  83.50  0.10  15.22  21.27  7.38 2023-09-29 23:30:00+00:00
# 2783  160.2  82.70  0.09  15.22  20.28  7.38 2023-09-29 23:45:00+00:00
#
# [2784 rows x 7 columns]

# %%
fig = df.plot(kind='line', title=['Conductivity','Dissolved Oxygen','Salinity','Temperature','Turbidly','pH',"umm"],
        figsize=(20, 16), fontsize=13, subplots=True,grid=True)
# fig = df.plot(kind='line',
#         figsize=(20, 16), fontsize=13, subplots=True,grid=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Kenji\Documents\Server Side Programming Projects\BlueColab_MobileDataViz\server\someTestingPlsIgnoreMe\data\whyPython.ipynb Cell 3 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kenji/Documents/Server%20Side%20Programming%20Projects/BlueColab_MobileDataViz/server/someTestingPlsIgnoreMe/data/whyPython.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> fig = df.plot(kind='line', title=['Conductivity','Dissolved Oxygen','Salinity','Temperature','Turbidly','pH'],
#       <a href='vscode-notebook-cell:/c%3A/Users/Kenji/Documents/Server%20Side%20Programming%20Projects/BlueColab_MobileDataViz/server/someTestingPlsIgnoreMe/data/whyPython.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a>         figsize=(20, 16), fontsize=13, subplots=True,grid=True)
#
# ...
